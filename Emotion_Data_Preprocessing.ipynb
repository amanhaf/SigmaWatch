# %% [markdown]
# The following code is written by Zhizuo Chen (aka George Chen).
#
# It pre-processes the data file "train_sent_emo_dya.csv":
#
# https://github.com/declare-lab/MELD/blob/master/data/MELD_Dyadic/train_sent_emo_dya.csv

# %%
import numpy as np, pandas as pd, time, math, random, scipy
from sklearn.preprocessing import LabelEncoder

# %%
#Function to change timestamps in "HH:MM:SS,mmm" to miliseconds.
def timestamp2int(time_stamp_str):

    #Get the hour, minute, second, and millisecond.
    hour, minute, rest = time_stamp_str.split(':')
    second, millisecond = rest.split(',')
    #Get the second in float format.
    return 1000 * (3600 * int(hour) + 60 * int(minute) + int(second)) + int(millisecond)
    #func-end

# %%
#Read the data.
df = pd.read_csv("train_sent_emo_dya.csv", header = 0)
#Drop irrelavant columns.
df.drop(columns = ['Sentiment', 'Dialogue_ID', 'Utterance_ID', 'Old_Dialogue_ID', 'Old_Utterance_ID'], inplace = True)
#Create LabelEncoder objects.
cod_speaker, cod_emotion = LabelEncoder(), LabelEncoder()
#Enode the 'Speaker' and 'Emotion' columns.
df['Speaker_coded'] = cod_speaker.fit_transform(df['Speaker'].values)
df['Emotion_coded'] = cod_emotion.fit_transform(df['Emotion'].values)
#Transform the 'StartTime' and 'EndTime' to float numbers.
df['StartTime_int'] = df['StartTime'].apply(timestamp2int)
df['EndTime_int'] = df['EndTime'].apply(timestamp2int)
#Drop original columns.
df.drop(columns = ['Speaker', 'Emotion', 'StartTime', 'EndTime'], inplace = True)
#Sorting the data.
df.sort_values(by = ['Season', 'Episode', 'StartTime_int'], ignore_index = True, inplace = True)
#Drop duplicates.
df.drop_duplicates(inplace = True)
#Move the 'Utterance' column to the last. 
col = df.pop('Utterance')
df.insert(len(df.columns), 'Utterance', col)

# %%
#Save the data file in csv format.
df.to_csv("emo_data.csv", header = True, index = False)
#Save the segmented data files by 'Season' and 'Episode' in csv format.
for (s, e), sub_df in df.groupby(['Season', 'Episode']):
    sub_df.to_csv("emo_data_s%02d_e%02d.csv" % (s, e), header = True, index = False)
    #for-end

# %%
#Display the encoding of 'Speaker'.
print("Speaker\tCode")
for i, s in enumerate(cod_speaker.classes_): print(s, '\t', i)
# Out:
# Speaker	Code
# 1st Customer 	 0
# 2nd Customer 	 1
# 3rd Customer 	 2
# A Female Student 	 3
# A Student 	 4
# Airline Employee 	 5
# Alice 	 6
# All 	 7
# Allesandro 	 8
# Angela 	 9
# Annabelle 	 10
# Another Scientist 	 11
# Another Tour Guide 	 12
# Aunt Lillian 	 13
# Barry 	 14
# Ben 	 15
# Bernice 	 16
# Bob 	 17
# Bobby 	 18
# Bonnie 	 19
# Both 	 20
# Boy in the Cape 	 21
# Burt 	 22
# Caitlin 	 23
# Carl 	 24
# Carol 	 25
# Casey 	 26
# Mr. Treeger 	 152
# Mr. Tribbiani 	 153
# Mr. Waltham 	 154
# Mr. Zelner 	 155
# Mrs. Burgin 	 156
# Mrs. Chatracus 	 157
# Mrs. Geller 	 158
# Mrs. Green 	 159
# Mrs. Lynch 	 160
# Mrs. Tedlock 	 161
# Mrs. Tribbiani 	 162
# Mrs. Waltham 	 163
# Ms. McKenna 	 164
# Nancy 	 165
# Nurse 	 166
# Nurse #1 	 167
# Nurse #2 	 168
# Older Scientist 	 169
# PBS Volunteer 	 170
# Paleontologist 	 171
# Paolo 	 172
# Paul 	 173
# Paula 	 174
# Pete 	 175
# Peter 	 176
# Petrie 	 177
# Phoebe 	 178
# Phoebe Sr 	 179
# Phoebe Sr. 	 180
# Phoebe and Rachel 	 181
# Phoebe/Waitress 	 182
# Policeman 	 183
# Professore Clerk 	 184
# Rachel 	 185
# Rachel and Phoebe 	 186
# Rachel/actress 	 187
# Raymond 	 188
# Receptionist 	 189
# Richard 	 190
# Richard’s Date 	 191
# Rick 	 192
# Robbie 	 193
# Robert 	 194
# Roger 	 195
# Ronni 	 196
# Ross 	 197
# Ross and Joey 	 198
# Russell 	 199
# Santos 	 200
# Sarah 	 201
# Sergei 	 202
# Shelley 	 203
# Sick Bastard 	 204
# Singer 	 205
# Sophie 	 206
# Stage Director 	 207
# Stanley 	 208
# Stephanie 	 209
# Steve 	 210
# Stevens 	 211
# Stranger 	 212
# Stu 	 213
# Student 	 214
# Supervisor 	 215
# Susan 	 216
# Tag 	 217
# Teacher 	 218
# Terry 	 219
# The Acting Teacher 	 220
# The Assistant Director 	 221
# The Casting Director 	 222
# The Cigarette Guy 	 223
# The Conductor 	 224
# The Cooking Teacher 	 225
# The Croupier 	 226
# The Director 	 227
# The Dry Cleaner 	 228
# The Fireman 	 229
# The Food Critic 	 230
# The Grip 	 231
# The Guys 	 232
# The Head Librarian 	 233
# The Instructor 	 234
# The Interviewer 	 235
# The Librarian 	 236
# The Lurker 	 237
# The Museum Official 	 238
# The Potential Roommate 	 239
# The Presenter 	 240
# The Security Guard 	 241
# The Singing Man 	 242
# The Smoking Woman 	 243
# The Vendor 	 244
# The Woman 	 245
# Ticket Counter Attendant 	 246
# Tom 	 247
# Tony 	 248
# Tour Guide 	 249
# Trudie Styler 	 250
# Ursula 	 251
# Vince 	 252
# Voice 	 253
# Waiter 	 254
# Wayne 	 255
# Woman 	 256
# Woman On Train 	 257
# Young Ethan 	 258
# an 	 259

# %%
#Display the encoding of 'Emotion'.
print("Emotion\tCode")
for i, s in enumerate(cod_emotion.classes_): print(s, '\t', i)
# Out:
# Emotion	Code
# anger 	 0
# disgust 	 1
# fear 	 2
# joy 	 3
# neutral 	 4
# sadness 	 5
# surprise 	 6
